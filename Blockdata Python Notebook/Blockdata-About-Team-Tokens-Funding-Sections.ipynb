# %%
# pip install selenium
# !pip install selenium

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import csv
import lxml

# %%
# Make an HTTP GET request to the main page URL
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.1234.56 Safari/537.36",
    "Referer": "https://www.example.com",
    "Accept-Language": "en-US,en;q=0.9"
}
url = "https://www.blockdata.tech/markets/use-cases"

# %%
response = requests.get(url, headers=headers)

# %%
# Parse the HTML content using Beautiful Soup
soup = BeautifulSoup(response.content, "lxml")

# %%
# Find the containers that hold the provider information
a_tags = soup.find_all('a')
print(a_tags)
# Out:
# [<a class="MuiButton-root MuiButton-contained MuiButton-containedPrimary MuiButton-sizeMedium MuiButton-containedSizeMedium MuiButtonBase-root css-4x5mqx" href="/login" tabindex="0">Log In</a>, <a href="/" style="color:inherit;text-decoration:none"><div class="MuiButtonBase-root MuiListItem-root MuiListItem-gutters MuiListItem-padding MuiListItem-button e170kkvm1 css-mb2n44" role="button" tabindex="0"><div class="MuiListItemIcon-root css-1f8bwsm"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-colorPrimary MuiSvgIcon-fontSizeMedium css-bbag3t" data-testid="HomeRoundedIcon" focusable="false" viewbox="0 0 24 24"><path d="M10 19v-5h4v5c0 .55.45 1 1 1h3c.55 0 1-.45 1-1v-7h1.7c.46 0 .68-.57.33-.87L12.67 3.6c-.38-.34-.96-.34-1.34 0l-8.36 7.53c-.34.3-.13.87.33.87H5v7c0 .55.45 1 1 1h3c.55 0 1-.45 1-1z"></path></svg></div><div class="MuiListItemText-root css-1tsvksn"><span class="MuiTypography-root MuiTypography-body1 MuiListItemText-primary css-c1yvd0">Home</span></div></div></a>, <a href="/blog" style="color:inherit;text-decoration:none"><div class="MuiButtonBase-root MuiListItem-root MuiListItem-gutters MuiListItem-padding MuiListItem-button e170kkvm1 css-mb2n44" role="button" tabindex="0"><div class="MuiListItemIcon-root css-1f8bwsm"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-colorPrimary MuiSvgIcon-fontSizeMedium css-bbag3t" data-testid="SubjectIcon" focusable="false" viewbox="0 0 24 24"><path d="M14 17H4v2h10v-2zm6-8H4v2h16V9zM4 15h16v-2H4v2zM4 5v2h16V5H4z"></path></svg></div><div class="MuiListItemText-root css-1tsvksn"><span class="MuiTypography-root MuiTypography-body1 MuiListItemText-primary css-c1yvd0">Research</span></div></div></a>, <a href="/profiles/vendors" style="color:inherit;text-decoration:none"><div class="MuiButtonBase-root MuiListItem-root MuiListItem-gutters MuiListItem-padding MuiListItem-button e170kkvm1 css-mb2n44" role="button" tabindex="0"><div class="MuiListItemIcon-root css-1f8bwsm"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-colorPrimary MuiSvgIcon-fontSizeMedium css-bbag3t" data-testid="AssignmentRoundedIcon" focusable="false" viewbox="0 0 24 24"><path d="M19 3h-4.18C14.4 1.84 13.3 1 12 1s-2.4.84-2.82 2H5c-1.1 0-2 .9-2 2v14c0 1.1.9 2 2 2h14c1.1 0 2-.9 2-2V5c0-1.1-.9-2-2-2zm-7 0c.55 0 1 .45 1 1s-.45 1-1 1-1-.45-1-1 .45-1 1-1zm1 14H8c-.55 0-1-.45-1-1s.45-1 1-1h5c.55 0 1 .45 1 1s-.45 1-1 1zm3-4H8c-.55 0-1-.45-1-1s.45-1 1-1h8c.55 0 1 .45 1 1s-.45 1-1 1zm0-4H8c-.55 0-1-.45-1-1s.45-1 1-1h8c.55 0 1 .45 1 1s-.45 1-1 1z"></path></svg></div><div class="MuiListItemText-root css-1tsvksn"><span class="MuiTypography-root MuiTypography-body1 MuiListItemText-primary css-c1yvd0">Profiles</span></div><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-fontSizeMedium css-11fo197" data-testid="ExpandMoreIcon" focusable="false" viewbox="0 0 24 24"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg></div></a>, <a href="/profiles/vendors" style="color:inherit;text-decoration:none"><div class="MuiButtonBase-root MuiListItem-root MuiListItem-gutters MuiListItem-padding MuiListItem-button e170kkvm1 css-103dae4" role="button" tabindex="0"><div class="MuiListItemText-root css-1tsvksn"><span class="MuiTypography-root MuiTypography-body1 MuiListItemText-primary css-c1yvd0">Vendors</span></div></div></a>, <a href="/tokens" style="color:inherit;text-decoration:none"><div class="MuiButtonBase-root MuiListItem-root MuiListItem-gutters MuiListItem-padding MuiListItem-button e170kkvm1 css-mb2n44" role="button" tabindex="0"><div class="MuiListItemIcon-root css-1f8bwsm"><svg aria-hidden="true" class="MuiSvgIcon-root MuiSvgIcon-colorPrimary MuiSvgIcon-fontSizeMedium css-bbag3t" data-testid="TripOriginIcon" focusable="false" viewbox="0 0 24 24"><path d="M2 12C2 6.48 6.48 2 12 2s10 4.48 10 10-4.48 10-10 10S2 17.52 2 12zm10 6c3.31 0 6-2.69 6-6s-2.69-6-6-6-6 2.69-6 6 2.69 6 6 6z"></path></svg></div><div class="MuiListItemText-root css-1tsvksn"><span class="MuiTypography-root MuiTypogr ...

# %%
links = [a["href"] for a in a_tags]
print(links)
# Out:
# ['/login', '/', '/blog', '/profiles/vendors', '/profiles/vendors', '/tokens', '/products', '/funding', '/learn', '/news', 'use-cases/access-control-system', 'use-cases/audit', 'use-cases/atm', 'use-cases/asset-tokenization', 'use-cases/autonomous-systems', 'use-cases/artificial-intelligence', 'use-cases/agriculture', 'use-cases/access-management', 'use-cases/analytics-and-research', 'use-cases/attention-economy', 'use-cases/asset-management', 'use-cases/algo-trading', 'use-cases/advertising-and-marketing', 'use-cases/automotive', 'use-cases/anti-counterfeiting', 'use-cases/booking-and-accomodation', 'use-cases/bill-of-lading', 'use-cases/blogging', 'use-cases/booking', 'use-cases/blockchain-advisory', 'use-cases/banking', 'use-cases/borrowing-and-lending', 'use-cases/business-tools', 'use-cases/blockchain-development-platform', 'use-cases/blockchain-as-a-service', 'use-cases/blockchain-services', 'use-cases/crypto-vendor', 'use-cases/capital-markets', 'use-cases/cannabis', 'use-cases/claims-management', 'use-cases/clearing-and-settlements', 'use-cases/cloud-computing', 'use-cases/civictech', 'use-cases/custody-solutions', 'use-cases/centralized-exchanges', 'use-cases/cross-border-payments', 'use-cases/crowdfunding', 'use-cases/cryptography', 'use-cases/cleantech', 'use-cases/cloud-data-services', 'use-cases/computer-vision', 'use-cases/compliance', 'use-cases/content-management', 'use-cases/consumer-electronics', 'use-cases/data-management', 'use-cases/digital-publishing', 'use-cases/derivatives', 'use-cases/digital-currencies', 'use-cases/data-sharing', 'use-cases/databases', 'use-cases/data-monetization', 'use-cases/documentation', 'use-cases/decentralized-applications', 'use-cases/decentralized-exchanges', 'use-cases/e-learning', 'use-cases/energy', 'use-cases/equity-management', 'use-cases/enterprise-service', 'use-cases/energy-trading', 'use-cases/end-to-end', 'use-cases/esports', 'use-cases/event-management', 'use-cases/exchanges-secondary-markets', 'use-cases/fundraising', 'use-cases/foreign-exchange', 'use-cases/financing', 'use-cases/freight-transport', 'use-cases/fraud-prevention', 'use-cases/fraud-and-risk-prevention', 'use-cases/financial-advisory', 'use-cases/governance', 'use-cases/gambling', 'use-cases/government-advisory', 'use-cases/gis-mapping', 'use-cases/gaming', 'use-cases/gps', 'use-cases/government-activities', 'use-cases/game-development', 'use-cases/health-insurance', 'use-cases/housing', 'use-cases/hardware', 'use-cases/hardware-infrastructure', 'use-cases/healthcare', 'use-cases/healthcare-services', 'use-cases/intellectual-property', 'use-cases/infrastructure', 'use-cases/identity-management-and-verification', 'use-cases/investment-banking', 'use-cases/intellectual-property-rights', 'use-cases/invoicing-and-billing', 'use-cases/ico-services', 'use-cases/insurance', 'use-cases/interoperability', 'use-cases/job-matching', 'use-cases/kyc-and-aml', 'use-cases/lending', 'use-cases/liquidity', 'use-cases/letter-of-credit', 'use-cases/location-networks', 'use-cases/liquidity-management', 'use-cases/login-solutions', 'use-cases/logistics', 'use-cases/loyalty-and-rewards', 'use-cases/land-registration', 'use-cases/mining-services', 'use-cases/marketplace', 'use-cases/microinsurance', 'use-cases/merchant-solutions', 'use-cases/micropayments', 'use-cases/music', 'use-cases/maintenance', 'use-cases/machine-learning', 'use-cases/mobility', 'use-cases/micro-tasking', 'use-cases/moving-services', 'use-cases/market-intelligence-services', 'use-cases/network-infrastructure', 'use-cases/notarization', 'use-cases/network-management', 'use-cases/news', 'use-cases/nft', 'use-cases/open-banking', 'use-cases/on-chain', 'use-cases/otc', 'use-cases/property-and-casualty-insurance', 'use-cases/payment-platform', 'use-cases/payment-service-provider', 'use-cases/project-management', 'use-cases/pre-trade', 'use-cases/pharma', 'use-cases/payment-processor', 'use-cases/point-of-sales', 'use-cases/post-trade', 'use-cases/payroll', ...

# %%
for link in links:
  print(link)
# Out:
# /login
# /
# /blog
# /profiles/vendors
# /profiles/vendors
# /tokens
# /products
# /funding
# /learn
# /news
# use-cases/access-control-system
# use-cases/audit
# use-cases/atm
# use-cases/asset-tokenization
# use-cases/autonomous-systems
# use-cases/artificial-intelligence
# use-cases/agriculture
# use-cases/access-management
# use-cases/analytics-and-research
# use-cases/attention-economy
# use-cases/asset-management
# use-cases/algo-trading
# use-cases/advertising-and-marketing
# use-cases/automotive
# use-cases/anti-counterfeiting
# use-cases/booking-and-accomodation
# use-cases/bill-of-lading
# use-cases/blogging
# use-cases/booking
# use-cases/blockchain-advisory
# use-cases/banking
# use-cases/borrowing-and-lending
# use-cases/business-tools
# use-cases/blockchain-development-platform
# use-cases/blockchain-as-a-service
# use-cases/blockchain-services
# use-cases/crypto-vendor
# use-cases/capital-markets
# use-cases/cannabis
# use-cases/claims-management
# use-cases/clearing-and-settlements
# use-cases/cloud-computing
# use-cases/civictech
# use-cases/custody-solutions
# use-cases/centralized-exchanges
# use-cases/cross-border-payments
# use-cases/crowdfunding
# use-cases/cryptography
# use-cases/cleantech
# use-cases/cloud-data-services
# use-cases/computer-vision
# use-cases/compliance
# use-cases/content-management
# use-cases/consumer-electronics
# use-cases/data-management
# use-cases/digital-publishing
# use-cases/derivatives
# use-cases/digital-currencies
# use-cases/data-sharing
# use-cases/databases
# use-cases/data-monetization
# use-cases/documentation
# use-cases/decentralized-applications
# use-cases/decentralized-exchanges
# use-cases/e-learning
# use-cases/energy
# use-cases/equity-management
# use-cases/enterprise-service
# use-cases/energy-trading
# use-cases/end-to-end
# use-cases/esports
# use-cases/event-management
# use-cases/exchanges-secondary-markets
# use-cases/fundraising
# use-cases/foreign-exchange
# use-cases/financing
# use-cases/freight-transport
# use-cases/fraud-prevention
# use-cases/fraud-and-risk-prevention
# use-cases/financial-advisory
# use-cases/governance
# use-cases/gambling
# use-cases/government-advisory
# use-cases/gis-mapping
# use-cases/gaming
# use-cases/gps
# use-cases/government-activities
# use-cases/game-development
# use-cases/health-insurance
# use-cases/housing
# use-cases/hardware
# use-cases/hardware-infrastructure
# use-cases/healthcare
# use-cases/healthcare-services
# use-cases/intellectual-property
# use-cases/infrastructure
# use-cases/identity-management-and-verification
# use-cases/investment-banking
# use-cases/intellectual-property-rights
# use-cases/invoicing-and-billing
# use-cases/ico-services
# use-cases/insurance
# use-cases/interoperability
# use-cases/job-matching
# use-cases/kyc-and-aml
# use-cases/lending
# use-cases/liquidity
# use-cases/letter-of-credit
# use-cases/location-networks
# use-cases/liquidity-management
# use-cases/login-solutions
# use-cases/logistics
# use-cases/loyalty-and-rewards
# use-cases/land-registration
# use-cases/mining-services
# use-cases/marketplace
# use-cases/microinsurance
# use-cases/merchant-solutions
# use-cases/micropayments
# use-cases/music
# use-cases/maintenance
# use-cases/machine-learning
# use-cases/mobility
# use-cases/micro-tasking
# use-cases/moving-services
# use-cases/market-intelligence-services
# use-cases/network-infrastructure
# use-cases/notarization
# use-cases/network-management
# use-cases/news
# use-cases/nft
# use-cases/open-banking
# use-cases/on-chain
# use-cases/otc
# use-cases/property-and-casualty-insurance
# use-cases/payment-platform
# use-cases/payment-service-provider
# use-cases/project-management
# use-cases/pre-trade
# use-cases/pharma
# use-cases/payment-processor
# use-cases/point-of-sales
# use-cases/post-trade
# use-cases/payroll
# use-cases/p2p-transactions
# use-cases/predictive-analytics
# use-cases/payment-gateway
# use-cases/privacy
# use-cases/provenance
# use-cases/payments-and-settlement
# use-cases/procurement
# use-cases/private-messaging
# use-cases/productivity
# use-cases/quantum-computing
# use-cases/royalties
# use-cases/remittances
# use-cases/retail
# use-cases/record-keeping
# use-cases/regulatory-compliance
# use-cases/reinsurance
# use-cases/rewarding
# use-cases/retail-banking
# use-cases/reporting
# use-cases/recruitment-services
# use-cases/research-and-development
# use-cases/reputation
# use-cases/robotics
# use-cases/sustainable-development
# use-cases/speech-recognition
# use-cases/sales-management
# use-cases/smart-house
# use-cases/software
# use-cases/sports-and-entertainment
# use-cases/sto-services
# use-cases/smart-contract-regulation
# use-cases/smart-contracts
# use-cases/social-impact
# use-cases/smart-city
# use-cases/social-networks
# use-cases/storage
# use-cases/scaling-solutions
# use-cases/social-media
# use-cases/smart-transport
# use-cases/supply-chain
# use-cases/supply-chain-management
# use-cases/security-services
# use-cases/sharing-economy
# use-cases/security
# use-cases/stablecoins
# use-cases/storage-solutions
# use-cases/security-exchange
# use-cases/supply-chain-finance
# use-cases/streaming
# use-cases/staking
# use-cases/saas
# use-cases/trading-analytics
# use-cases/trade-finance
# use-cases/tax-automation
# use-cases/traceability
# use-cases/tracking-and-monitoring
# use-cases/travel-insurance
# use-cases/talent-management
# use-cases/ticketing
# use-cases/transparent-audits
# use-cases/uav
# use-cases/voting
# use-cases/venture-capital
# use-cases/virtual-reality
# use-cases/workflow-automation
# use-cases/wealth-management
# use-cases/wallets
# use-cases/yield-farming
# /
# https://coda.io/form/Blockdata-feedback-form_dnok_FFbXZW
# https://www.blockdata.tech/markets/industries
# https://www.blockdata.tech/markets/use-cases
# https://about.blockdata.tech/vendors
# https://about.blockdata.tech/contact-us
# /blog
# https://about.blockdata.tech/datapolicy
# https://about.blockdata.tech/contentpolicy
# https://about.blockdata.tech/termsandconditions
# https://about.blockdata.tech/privacypolicy
# https://twitter.com/blockdata_tech?lang=en
# https://www.linkedin.com/company/blockdata/
# https://about.blockdata.tech/

# %%
filtered_links = [link for link in links if link.startswith("use-cases")]

# %%
print(filtered_links)
# filename = "blockdata-usecases-links.csv"
# Out:
# ['use-cases/access-control-system', 'use-cases/audit', 'use-cases/atm', 'use-cases/asset-tokenization', 'use-cases/autonomous-systems', 'use-cases/artificial-intelligence', 'use-cases/agriculture', 'use-cases/access-management', 'use-cases/analytics-and-research', 'use-cases/attention-economy', 'use-cases/asset-management', 'use-cases/algo-trading', 'use-cases/advertising-and-marketing', 'use-cases/automotive', 'use-cases/anti-counterfeiting', 'use-cases/booking-and-accomodation', 'use-cases/bill-of-lading', 'use-cases/blogging', 'use-cases/booking', 'use-cases/blockchain-advisory', 'use-cases/banking', 'use-cases/borrowing-and-lending', 'use-cases/business-tools', 'use-cases/blockchain-development-platform', 'use-cases/blockchain-as-a-service', 'use-cases/blockchain-services', 'use-cases/crypto-vendor', 'use-cases/capital-markets', 'use-cases/cannabis', 'use-cases/claims-management', 'use-cases/clearing-and-settlements', 'use-cases/cloud-computing', 'use-cases/civictech', 'use-cases/custody-solutions', 'use-cases/centralized-exchanges', 'use-cases/cross-border-payments', 'use-cases/crowdfunding', 'use-cases/cryptography', 'use-cases/cleantech', 'use-cases/cloud-data-services', 'use-cases/computer-vision', 'use-cases/compliance', 'use-cases/content-management', 'use-cases/consumer-electronics', 'use-cases/data-management', 'use-cases/digital-publishing', 'use-cases/derivatives', 'use-cases/digital-currencies', 'use-cases/data-sharing', 'use-cases/databases', 'use-cases/data-monetization', 'use-cases/documentation', 'use-cases/decentralized-applications', 'use-cases/decentralized-exchanges', 'use-cases/e-learning', 'use-cases/energy', 'use-cases/equity-management', 'use-cases/enterprise-service', 'use-cases/energy-trading', 'use-cases/end-to-end', 'use-cases/esports', 'use-cases/event-management', 'use-cases/exchanges-secondary-markets', 'use-cases/fundraising', 'use-cases/foreign-exchange', 'use-cases/financing', 'use-cases/freight-transport', 'use-cases/fraud-prevention', 'use-cases/fraud-and-risk-prevention', 'use-cases/financial-advisory', 'use-cases/governance', 'use-cases/gambling', 'use-cases/government-advisory', 'use-cases/gis-mapping', 'use-cases/gaming', 'use-cases/gps', 'use-cases/government-activities', 'use-cases/game-development', 'use-cases/health-insurance', 'use-cases/housing', 'use-cases/hardware', 'use-cases/hardware-infrastructure', 'use-cases/healthcare', 'use-cases/healthcare-services', 'use-cases/intellectual-property', 'use-cases/infrastructure', 'use-cases/identity-management-and-verification', 'use-cases/investment-banking', 'use-cases/intellectual-property-rights', 'use-cases/invoicing-and-billing', 'use-cases/ico-services', 'use-cases/insurance', 'use-cases/interoperability', 'use-cases/job-matching', 'use-cases/kyc-and-aml', 'use-cases/lending', 'use-cases/liquidity', 'use-cases/letter-of-credit', 'use-cases/location-networks', 'use-cases/liquidity-management', 'use-cases/login-solutions', 'use-cases/logistics', 'use-cases/loyalty-and-rewards', 'use-cases/land-registration', 'use-cases/mining-services', 'use-cases/marketplace', 'use-cases/microinsurance', 'use-cases/merchant-solutions', 'use-cases/micropayments', 'use-cases/music', 'use-cases/maintenance', 'use-cases/machine-learning', 'use-cases/mobility', 'use-cases/micro-tasking', 'use-cases/moving-services', 'use-cases/market-intelligence-services', 'use-cases/network-infrastructure', 'use-cases/notarization', 'use-cases/network-management', 'use-cases/news', 'use-cases/nft', 'use-cases/open-banking', 'use-cases/on-chain', 'use-cases/otc', 'use-cases/property-and-casualty-insurance', 'use-cases/payment-platform', 'use-cases/payment-service-provider', 'use-cases/project-management', 'use-cases/pre-trade', 'use-cases/pharma', 'use-cases/payment-processor', 'use-cases/point-of-sales', 'use-cases/post-trade', 'use-cases/payroll', 'use-cases/p2p-transactions', 'use-cases/predictive-analytics', 'use-cases/payment-gateway', 'use-cases/privacy', 'use-c ...

# %%
base_url_for_use_cases = 'https://www.blockdata.tech/markets/'
filename = 'all_use_cases_sheet.csv'
with open(filename, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Base Url','Use Case'])

    for use_case in filtered_links:
        writer.writerow([base_url_for_use_cases, use_case])

# %%
# So now - beginning of the step where i want to append the use-cases to the base url and iterate over the pages to obtain the links to the profiles.
base_url = 'https://www.blockdata.tech/markets/'
use_cases_url_list = []

# Original code
for use_case in filtered_links:
  url = base_url + use_case
  use_cases_url_list.append(url)

# %%
print(use_cases_url_list)
# Out:
# ['https://www.blockdata.tech/markets/use-cases/access-control-system', 'https://www.blockdata.tech/markets/use-cases/audit', 'https://www.blockdata.tech/markets/use-cases/atm', 'https://www.blockdata.tech/markets/use-cases/asset-tokenization', 'https://www.blockdata.tech/markets/use-cases/autonomous-systems', 'https://www.blockdata.tech/markets/use-cases/artificial-intelligence', 'https://www.blockdata.tech/markets/use-cases/agriculture', 'https://www.blockdata.tech/markets/use-cases/access-management', 'https://www.blockdata.tech/markets/use-cases/analytics-and-research', 'https://www.blockdata.tech/markets/use-cases/attention-economy', 'https://www.blockdata.tech/markets/use-cases/asset-management', 'https://www.blockdata.tech/markets/use-cases/algo-trading', 'https://www.blockdata.tech/markets/use-cases/advertising-and-marketing', 'https://www.blockdata.tech/markets/use-cases/automotive', 'https://www.blockdata.tech/markets/use-cases/anti-counterfeiting', 'https://www.blockdata.tech/markets/use-cases/booking-and-accomodation', 'https://www.blockdata.tech/markets/use-cases/bill-of-lading', 'https://www.blockdata.tech/markets/use-cases/blogging', 'https://www.blockdata.tech/markets/use-cases/booking', 'https://www.blockdata.tech/markets/use-cases/blockchain-advisory', 'https://www.blockdata.tech/markets/use-cases/banking', 'https://www.blockdata.tech/markets/use-cases/borrowing-and-lending', 'https://www.blockdata.tech/markets/use-cases/business-tools', 'https://www.blockdata.tech/markets/use-cases/blockchain-development-platform', 'https://www.blockdata.tech/markets/use-cases/blockchain-as-a-service', 'https://www.blockdata.tech/markets/use-cases/blockchain-services', 'https://www.blockdata.tech/markets/use-cases/crypto-vendor', 'https://www.blockdata.tech/markets/use-cases/capital-markets', 'https://www.blockdata.tech/markets/use-cases/cannabis', 'https://www.blockdata.tech/markets/use-cases/claims-management', 'https://www.blockdata.tech/markets/use-cases/clearing-and-settlements', 'https://www.blockdata.tech/markets/use-cases/cloud-computing', 'https://www.blockdata.tech/markets/use-cases/civictech', 'https://www.blockdata.tech/markets/use-cases/custody-solutions', 'https://www.blockdata.tech/markets/use-cases/centralized-exchanges', 'https://www.blockdata.tech/markets/use-cases/cross-border-payments', 'https://www.blockdata.tech/markets/use-cases/crowdfunding', 'https://www.blockdata.tech/markets/use-cases/cryptography', 'https://www.blockdata.tech/markets/use-cases/cleantech', 'https://www.blockdata.tech/markets/use-cases/cloud-data-services', 'https://www.blockdata.tech/markets/use-cases/computer-vision', 'https://www.blockdata.tech/markets/use-cases/compliance', 'https://www.blockdata.tech/markets/use-cases/content-management', 'https://www.blockdata.tech/markets/use-cases/consumer-electronics', 'https://www.blockdata.tech/markets/use-cases/data-management', 'https://www.blockdata.tech/markets/use-cases/digital-publishing', 'https://www.blockdata.tech/markets/use-cases/derivatives', 'https://www.blockdata.tech/markets/use-cases/digital-currencies', 'https://www.blockdata.tech/markets/use-cases/data-sharing', 'https://www.blockdata.tech/markets/use-cases/databases', 'https://www.blockdata.tech/markets/use-cases/data-monetization', 'https://www.blockdata.tech/markets/use-cases/documentation', 'https://www.blockdata.tech/markets/use-cases/decentralized-applications', 'https://www.blockdata.tech/markets/use-cases/decentralized-exchanges', 'https://www.blockdata.tech/markets/use-cases/e-learning', 'https://www.blockdata.tech/markets/use-cases/energy', 'https://www.blockdata.tech/markets/use-cases/equity-management', 'https://www.blockdata.tech/markets/use-cases/enterprise-service', 'https://www.blockdata.tech/markets/use-cases/energy-trading', 'https://www.blockdata.tech/markets/use-cases/end-to-end', 'https://www.blockdata.tech/markets/use-cases/esports', 'https://www.blockdata.tech/markets/use-cases/event-management', 'h ...

# %%
# So at this point now want to make requests to the use-cases page to scrap the profile links
profiles_list = []
for use_case_url in use_cases_url_list:
  response = requests.get(use_case_url, headers=headers)
  soup = BeautifulSoup(response.content, "lxml")
  prettified_html = soup.prettify()
  link_tags = soup.find_all("a", class_="MuiButton-root MuiButton-outlined MuiButton-outlinedPrimary MuiButton-sizeMedium MuiButton-outlinedSizeMedium MuiButtonBase-root index-button css-sgl86c")
  links = [a["href"] for a in link_tags]
  for link in links:
    if link not in profiles_list:
      profiles_list.append(link)
print(profiles_list)
# Out:
# ['/profiles/sweatcoin', '/profiles/medicalchain', '/profiles/hearthy', '/profiles/mint-health', '/profiles/apotheka', '/profiles/eggschain', '/profiles/certik', '/profiles/openzeppelin', '/profiles/hacken', '/profiles/ethsign', '/profiles/hashex', '/profiles/metatrust', '/profiles/lukka', '/profiles/memento-blockchain', '/profiles/beosin', '/profiles/quantstamp', '/profiles/vertalo', '/profiles/dedaub', '/profiles/alkemi-network', '/profiles/safeheron', '/profiles/quadrata', '/profiles/olympix', '/profiles/salus-security', '/profiles/immunebytes', '/profiles/secure3', '/profiles/forta', '/profiles/chainsecurity', '/profiles/blocksec', '/profiles/hexens', '/profiles/code4rena', '/profiles/universal-plastic', '/profiles/servblock', '/profiles/tres', '/profiles/shield-1', '/profiles/freeran-ge', '/profiles/sec3', '/profiles/bit2me', '/profiles/bitaccess', '/profiles/coinme', '/profiles/coinflip', '/profiles/intellogate', '/profiles/btcpoint', '/profiles/goldmint', '/profiles/instacoin', '/profiles/xbteller', '/profiles/belcobtm', '/profiles/pay-depot', '/profiles/coinsource', '/profiles/localcoin', '/profiles/general-bytes', '/profiles/lamassu', '/profiles/rockitcoin', '/profiles/coincloud', '/profiles/digitalmint', '/profiles/bitstop', '/profiles/bitcoin-depot', '/profiles/bayside', '/profiles/covault', '/profiles/genesis-coin', '/profiles/national-bitcoin-atm', '/profiles/binance', '/profiles/tzero', '/profiles/securitize', '/profiles/seba-bank', '/profiles/addx', '/profiles/polymath', '/profiles/allianceblock-1', '/profiles/vechain-1', '/profiles/japan-exchange-group', '/profiles/reef', '/profiles/xdc-network', '/profiles/tokensoft', '/profiles/swarm', '/profiles/netvrk', '/profiles/tokeny-solutions', '/profiles/bankex', '/profiles/alphapoint', '/profiles/symbiont', '/profiles/powerpool', '/profiles/stokr', '/profiles/riddle-and-code', '/profiles/weown', '/profiles/fnality', '/profiles/codefi', '/profiles/commonwealth-bank-blockchain-commbank', '/profiles/archax', '/profiles/trustswap', '/profiles/securrency', '/profiles/dusk-network', '/profiles/aragon', '/profiles/skyfchain', '/profiles/limitless-holding', '/profiles/cortex', '/profiles/iluma', '/profiles/mysocialpulse', '/profiles/sensor-link', '/profiles/sandboxaq', '/profiles/ors-group', '/profiles/fetch-ai', '/profiles/satoshi-systems', '/profiles/petuum', '/profiles/solidus-labs', '/profiles/barca-vision', '/profiles/narvar', '/profiles/anchain-ai', '/profiles/digiledge', '/profiles/trapx-security', '/profiles/coinvest', '/profiles/bibox-technology-ltd', '/profiles/bond-financial-technologies', '/profiles/aspecta', '/profiles/indico', '/profiles/points', '/profiles/klue', '/profiles/oben', '/profiles/cryptogpt', '/profiles/ikioo-technologies', '/profiles/opensc', '/profiles/neocortexai', '/profiles/altoros', '/profiles/irreverent-labs', '/profiles/idnow', '/profiles/humans-ai', '/profiles/fitbeat', '/profiles/adhive', '/profiles/ufin', '/profiles/farmer-connect', '/profiles/sap-consumer-goods-retails-and-agribusiness-consortium', '/profiles/gavea-marketplace', '/profiles/cystellar', '/profiles/sniffer-labs', '/profiles/the-growhub', '/profiles/agunity', '/profiles/emertech-solutions', '/profiles/shamba-records', '/profiles/bart-digital', '/profiles/ibisa', '/profiles/greens', '/profiles/agri10x', '/profiles/taxbit', '/profiles/torus-labs', '/profiles/nil-foundation-nil-foundation', '/profiles/fortknoxster', '/profiles/hypermine', '/profiles/spruce', '/profiles/hypernet', '/profiles/identitypass', '/profiles/block-armour', '/profiles/nucypher', '/profiles/lonestar-data-technologies', '/profiles/proven', '/profiles/mpch-labs', '/profiles/indicio', '/profiles/corsha', '/profiles/taekion', '/profiles/custonomy', '/profiles/sovrin', '/profiles/cyvers', '/profiles/dynamic-1', '/profiles/agridigital', '/profiles/team-finance', '/profiles/clerk', '/profiles/quantum-resistant-cryptography-qrc', '/profiles/aid-tech', '/profiles/nucleo', '/profiles/ucrop-it', '/profiles/prager-met ...

# %%
# Writing data to the csv file
base_url_for_profiles = 'https://www.blockdata.tech'
with open("all_profiles_data.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Base URL", "Link"])  # Write the header row
    for link in profiles_list:
        writer.writerow([base_url_for_profiles, link])

# %%
# Now for scrapping the info on the profile page part
# We have access to the links stored in the profiles_list array
# test urls to scrap - '/profiles/sweatcoin', '/profiles/medicalchain'
import time

# '/profiles/sweatcoin','/profiles/medicalchain', '/profiles/hearthy',
test_profiles_list_urls = [ '/profiles/coinbase']

# So i need to write data to several csv files
# 1 - Blockdata-about-section (Already have this one)
# 2 - Team section (Just gonna save the profile link and Name, and rest of team section)
# 3 - Customers / Partners section
# 4 - Products section csv
# 5 - Funding section
# 6 - News section

about_section_sheet = 'Blockdata-about-section.csv'
team_section_sheet = 'Blockdata-team-section.csv'
partners_section_sheet = 'Blockdata-partners-section.csv'
products_section_sheet = 'Blockdata-products-section.csv'
funding_section_sheet = 'Blockdata-funding-section.csv'
news_section_sheet = 'Blockdata-news-section.csv'
tokens_sheet = 'Blockdata-tokens-section.csv'

with open(about_section_sheet, "w", encoding='utf-8', newline="") as about_section_csv, \
     open(team_section_sheet, "w", encoding='utf-8', newline="") as team_section_csv, \
     open(partners_section_sheet, "w",encoding='utf-8', newline="") as partners_section_csv, \
     open(products_section_sheet, "w",encoding='utf-8', newline="") as products_section_csv, \
     open(funding_section_sheet, "w",encoding='utf-8', newline="") as funding_section_csv, \
     open(tokens_sheet, "w",encoding='utf-8', newline="") as tokens_sheet_csv, \
     open(news_section_sheet, "w",encoding='utf-8', newline="") as news_section_csv:

    about_section_writer = csv.writer(about_section_csv)
    about_section_writer.writerow(["Profile Link","Name","Profile Bio", "Logo Url", "Caption", "Description", "Based In", "Website Url", "LinkedIn", "Twitter", "Facebook", "Telegram", "Github", "Reddit",
                     "Medium", "Total Amount Raised", "Team Size", "Number Of Clients", "Year of establishment", "Profile Type", "Status" , "Key Objective",
                     "Slogan / Motto", "Use cases", "Parent Organizations","Sub Organization", "Registered Entity Name"])

    team_section_writer = csv.writer(team_section_csv)
    team_section_writer.writerow(["Profile Link", "Name", "Team member, Responsibility and LinkedIn Profile"])

    partners_section_writer = csv.writer(partners_section_csv)
    partners_section_writer.writerow(["Profile Link", "Name"])

    products_section_writer = csv.writer(products_section_csv)
    products_section_writer.writerow(["Profile Link", "Name"])

    funding_section_writer = csv.writer(funding_section_csv)
    funding_section_writer.writerow(["Profile Link", "Name", "Total Amount Raised", "Received Funding Rounds", "Total Amount Of Investors", "List Of Received Funding",
       "Investment Rounds", "Total Amount Of Profiles", "List Of Investments"])

    tokens_section_writer = csv.writer(tokens_sheet_csv)
    tokens_section_writer.writerow(["Profile Link", "Name", "Token Name","Token Symbol", "Type", "Runs on", "Token Standards", "Price", "Market Cap", "Link To Token" ])

    news_section_writer = csv.writer(news_section_csv)
    news_section_writer.writerow(["Profile Link", "Name"])


    for url in profiles_list:
      full_endpoint = base_url_for_profiles + url
      response = requests.get(full_endpoint, headers=headers)
      soup = BeautifulSoup(response.content, "lxml")
      prettified_html = soup.prettify()

      # Extract the string company name for example "sweatcoin || coinbase" from the test_url
      string_to_extract = url.split('/')[-1]
      extracted_string = string_to_extract.capitalize()

      #0 - The Profile Link
      profile_link = base_url_for_profiles + url

      # Now writing the code to extract different data points in the response html
      # 1 - The image tag
      image_tag = soup.find('img', alt=extracted_string)

      if image_tag:
        # Extract the image source attribute
        image_url = image_tag['src']
      else:
        image_url = 'N/A'

      # 2 - Company name
      header_tag = soup.find('h1', class_="MuiTypography-root MuiTypography-h3 css-1vj7cda")
      if header_tag:
        company_name = header_tag.get_text()
      else:
        company_name = 'N/A'

      # 3 - Caption
      span_tag = soup.find('span', class_="MuiTypography-root MuiTypography-caption css-2wkurb")
      if span_tag:
        company_caption = span_tag.get_text()
      else:
        company_caption = 'N/A'

      # 4 - Company description
      description_p_tag = soup.find('p', class_="MuiTypography-root MuiTypography-body1 css-yt6mq")
      if description_p_tag:
        company_description = description_p_tag.get_text()
      else:
        company_description = 'N/A'

      # 5 - Based in
      p_tag = soup.find('p', class_="MuiTypography-root MuiTypography-body1 css-1cghcd7")
      if p_tag:
        based_in = p_tag.get_text()
      else:
        based_in = 'N/A'

      # 6 - Website url
      a_tag = soup.find('a', class_="MuiButtonBase-root MuiIconButton-root MuiIconButton-colorPrimary MuiIconButton-sizeMedium css-6n14gx")
      if a_tag:
        website_url = a_tag["href"]
      else:
        website_url = 'N/A'


      #7 - Linked in profile
      a_tag = soup.find('a', class_="MuiButtonBase-root MuiIconButton-root MuiIconButton-colorPrimary MuiIconButton-sizeLarge e8femqp0 css-racc64")
      if a_tag:
        linked_in_profile = a_tag["href"]
      else:
        linked_in_profile = 'N/A'

      # 8 - Twitter link
      a_tag = soup.find('a', class_="MuiButtonBase-root MuiIconButton-root MuiIconButton-colorPrimary MuiIconButton-sizeSmall e8femqp0 css-103bd9p")
      if a_tag:
        twitter_handle = a_tag["href"]
      else:
        twitter_handle = 'N/A'

      # 9 - Facebook link
      a_tag = soup.find('a', attrs={'aria-label': 'Facebook'})

      if a_tag:
        facebook_page = a_tag.get('href')
      else:
        facebook_page = 'N/A'

      # 10 - Telegram
      a_tag = soup.find('a', attrs={'aria-label': 'Telegram'})

      if a_tag:
        telegram_handle = a_tag.get('href')
      else:
        telegram_handle = 'N/A'

      # 11 - Github repo
      a_tag = soup.find('a', attrs={'aria-label': 'Github'})

      if a_tag:
        github_repo = a_tag.get('href')
      else:
        github_repo = 'N/A'

      # 12 - Reddit
      a_tag = soup.find('a', attrs={'aria-label': 'Reddit'})

      if a_tag:
        reddit_url = a_tag.get('href')
      else:
        reddit_url = 'N/A'

      # 13 - Medium
      a_tag = soup.find('a', attrs={'aria-label': 'Medium'})

      if a_tag:
        medium_url = a_tag.get('href')
      else:
        medium_url = 'N/A'

      # 14 Total amount raised
      parent_div = soup.find('div', class_='MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation0 eegbixt0 css-1jcw4ls')

      total_amount_raised = 'N/A'
      if parent_div:
        total_amount_div = parent_div.find('div', class_='MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom css-zd7onr')
        if total_amount_div:
            total_amount_raised = total_amount_div.get_text()

      # 14 team size
      parent_div = soup.find('div', class_='MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation0 e1azb2kh0 css-1jcw4ls')

      team_size = 'N/A'
      if parent_div:
        team_size_div = parent_div.find('div', class_='MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom css-zd7onr')
        if team_size_div:
            team_size = team_size_div.get_text()


      # 15 - Number of clients
      parent_div = soup.find('div', class_='MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation0 e1l5eb8a0 css-1jcw4ls')

      number_of_clients = 'N/A'
      if parent_div:
        clients_div = parent_div.find('div', class_='MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom css-zd7onr')
        if clients_div:
            number_of_clients = clients_div.get_text()

      # 16 - Year of establishment
      parent_div = soup.find('div', class_='MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation0 ew5h1nx0 css-1jcw4ls')

      year_of_establishment = 'N/A'
      if parent_div:
        year_div = parent_div.find('div', class_='MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom css-zd7onr')
        if year_div:
            year_of_establishment = year_div.get_text()

      #17 Profile type
      parent_div = soup.find('div', class_='MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation0 e4tqbn60 css-tpf8av')

      profile_type = 'N/A'
      if parent_div:
        company_div = parent_div.find('div', class_='MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom css-zd7onr')
        if company_div:
            profile_type = company_div.get_text()

      #18 - Status
      parent_div = soup.find('div', class_='MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation0 ezqtn1f1 css-1jcw4ls')

      status = 'N/A'
      if parent_div:
        status_div = parent_div.find('div', class_='MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom ezqtn1f0 css-fsjm1')
        if status_div:
            status = status_div.get_text()

      #19 - The Key Objective
      key_objective = 'N/A'
      p_tag = soup.find('p' , class_="MuiTypography-root MuiTypography-body1 MuiTypography-alignLeft css-1h7tlwk")
      if p_tag:
        key_objective = p_tag.get_text()

      # Here is the point i stopped updating my csv headers

      #20 - Slogan / Motto
      slogan_motto = 'N/A'
      p_tag = soup.find('p' , class_="MuiTypography-root MuiTypography-body1 MuiTypography-alignLeft css-1x3i4xu")
      if p_tag:
        slogan_motto = p_tag.get_text()

      #21 - Use cases
      use_cases = []
      div_element = soup.find('div', class_='css-a696o0 e1rt5nlw1')

      if div_element:
        span_elements = div_element.find_all('span', class_='MuiChip-label MuiChip-labelMedium css-14vsv3w')
        use_cases = [span.get_text() for span in span_elements]

      #22 - Parent organization
      parent_organization = []
      div_element = soup.find('div', class_='MuiGrid-root MuiGrid-container MuiGrid-item css-n6nfem')

      if div_element:
          span_elements = div_element.find_all('span', class_='MuiChip-label MuiChip-labelSmall css-tavflp')
          parent_organization = [span.get_text() for span in span_elements]

      #23 - Sub organizations
      sub_organization = []
      div_element = soup.find_all('div' , class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-6 MuiGrid-grid-md-9 css-q25qnl")
      if len(div_element) > 1:
        element_i_want = div_element[1].find_all('span', class_="MuiChip-label MuiChip-labelSmall css-tavflp")
        for every_span in element_i_want:
          sub_organization.append(every_span.get_text())
      else:
        sub_organization = 'N/A'

      # 24 - Registered Entity Name
      registered_entity_name = 'N/A'
      div_element = soup.find_all('div' , class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-6 MuiGrid-grid-md-9 css-q25qnl")
      if(len(div_element)) > 2:
          element_i_want = div_element[2].find('p', class_="MuiTypography-root MuiTypography-body1 css-yt6mq")
          registered_entity_name = element_i_want.get_text()



        # # Code for writing to the csv file
      
      # Also get the bio using pyppeteer

      import asyncio
      from pyppeteer import launch
      import nest_asyncio

      async def get_profile_bio():
        try:
            browser = await launch()
            page = await browser.newPage()
            full_url = 'https://www.blockdata.tech/' + url
            await page.goto(full_url)

            show_more_button = await page.querySelector('.css-1o4oh22.e1pn9n6e0')
            if show_more_button:
                await show_more_button.click()

            # await page.waitForSelector('.MuiGrid-root.MuiGrid-item.MuiGrid-grid-xs-12.MuiGrid-grid-sm-6.MuiGrid-grid-md-8.css-1yz5cc4', {'timeout': 10000})

            extracted_text = await page.evaluate('document.querySelector(".MuiGrid-root.MuiGrid-item.MuiGrid-grid-xs-12.MuiGrid-grid-sm-6.MuiGrid-grid-md-8.css-1yz5cc4").textContent')

            await browser.close()
            return extracted_text
        except TimeoutError:
            print("Timeout error occurred.")
            return 'N/A'

      # Allow running nested asyncio event loops
      nest_asyncio.apply()

      # Run the event loop in the notebook
      loop = asyncio.get_event_loop()
      profile_bio = loop.run_until_complete(get_profile_bio())
      
      
      about_section_writer.writerow([profile_link, company_name,profile_bio,
                         image_url, company_caption,
                         company_description, based_in, website_url,
                         linked_in_profile, twitter_handle,facebook_page,
                         telegram_handle, github_repo, reddit_url,medium_url,
                         total_amount_raised,team_size,number_of_clients,year_of_establishment,
                         profile_type,status, key_objective, slogan_motto, use_cases, parent_organization,sub_organization, registered_entity_name ])

      # Beginning scrap of the team section
      # 25 - Team members section
      #So in this section will come back later and scrap the responsibility which have a show more button
      team_members = []
      grid_element = soup.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-item MuiGrid-spacing-xs-2 css-5g8fo7")
      if grid_element:
        single_element_in_grid = grid_element.find_all('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 MuiGrid-grid-sm-6 css-rpybyc")
        if(single_element_in_grid):
          for element in single_element_in_grid:
            team_member_detail_div = element.find('div', class_="MuiPaper-root MuiPaper-outlined MuiPaper-rounded css-1avv7jm")
            container_div_with_all_details_for_team_member = team_member_detail_div.find('div', class_="MuiGrid-root MuiGrid-container css-1d3bbye")
            linkedIn = container_div_with_all_details_for_team_member.find('a', class_='MuiButtonBase-root MuiIconButton-root MuiIconButton-colorPrimary MuiIconButton-sizeLarge erjqhew0 css-q372t6')
            if linkedIn:
              linkedIn = linkedIn["href"]
            # First get their name and last their linked in
            member_name_and_responsibility = container_div_with_all_details_for_team_member.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-item MuiGrid-direction-xs-column MuiGrid-grid-xs-true css-1injdr0")
            if member_name_and_responsibility:
              name = member_name_and_responsibility.find('span', class_="MuiTypography-root MuiTypography-body3 MuiTypography-gutterBottom css-1d2t6we")
              name_and_job_responsibility = name.get_text()
              name_responsibility_and_linkedin_combined_into_list = [name_and_job_responsibility, linkedIn]
              team_members.append(name_responsibility_and_linkedin_combined_into_list)
      else:
        team_members = 'N/A'
      
      ## Scrapping the tokens and funding section
      # Tokens
      #26 - Tokens
      # Token Info Array
      token_info = []
      token_names = []
      tokens_section = soup.find('div', class_="MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation1 MuiCard-root index-root css-1tgiuf5")
      if tokens_section:
        sub_tokens_section_div = tokens_section.find('div', class_="MuiCardContent-root index-content css-1qw96cp")
        if sub_tokens_section_div:
          flex_container_containing_token_info = sub_tokens_section_div.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-3 index-cardContentGrid css-s2t2cz")
          individual_div_containing_token_info = flex_container_containing_token_info.find_all('div', class_="MuiGrid-root MuiGrid-item css-1wxaqej")
          if individual_div_containing_token_info:
            for each_div in individual_div_containing_token_info:
              p_tag = each_div.find('p', class_="MuiTypography-root MuiTypography-body1 e1ontwvu1 css-1jeqi5i")
              if p_tag:
                token_names.append(p_tag.get_text())
              tag_h6 = each_div.find('h6' , class_="MuiTypography-root MuiTypography-subtitle2 css-1whifbp")
              if tag_h6:
                tag_h6 = tag_h6.get_text()
              token_info.append(tag_h6)
      else:
        token_info = 'N/A'

      link_to_token = 'N/A'
      if tokens_section:
        a_tag_container = tokens_section.find('div', class_="MuiCardActions-root css-jo6j44")
        if a_tag_container:
          a_tag = a_tag_container.find('a', class_="MuiButton-root MuiButton-text MuiButton-textPrimary MuiButton-sizeSmall MuiButton-textSizeSmall MuiButtonBase-root css-x16yd0")
          if a_tag:
            link_to_token = a_tag["href"]
            base_url_for_tokens = "https://www.blockdata.tech"
            link_to_token = base_url_for_tokens + link_to_token
            token_info.append(link_to_token)
      
      # Now for scrapping the funding section
      total_amount_raised = 'N/A'
      rounds = 'N/A'
      total_amount_of_investors = 'N/A'
      funding_sources = []
      funding_section = soup.find('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 ehdjfxk0 css-1lk7s4z")
      if funding_section:
        sub_section = funding_section.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-8 css-1l5mznc")
        if sub_section:
          first_container = sub_section.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-item MuiGrid-spacing-xs-3 css-1ofn76x")
          if first_container:
            items_list_in_the_first_container = first_container.find_all('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-4 css-idrrft")
            if items_list_in_the_first_container:
              #1 - Total amount raised
              if len(items_list_in_the_first_container) > 1:
                #I want to take the fist item in the list
                item = items_list_in_the_first_container[0].find('div', class_="MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom index-count css-1axqeeq")
                total_amount_raised = item.get_text()
              
              #2 - Rounds
              if len(items_list_in_the_first_container) > 2:
                #I want to take the fist item in the list
                item = items_list_in_the_first_container[1].find('div', class_="MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom index-count css-1axqeeq")
                rounds = item.get_text()
              

              #3 - Rounds
              if len(items_list_in_the_first_container) >= 3:
                #I want to take the fist item in the list
                item = items_list_in_the_first_container[2].find('div', class_="MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom index-count css-1axqeeq")
                total_amount_of_investors = item.get_text()

        #2 - Funding sources
        source_object = {}
        sources = []
        second_sub_section = funding_section.find('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 css-15j76c0")
        if second_sub_section:
          inner_section = second_sub_section.find('div', class_="css-1akhy6d e5y0f1k0")
          if inner_section:
            table_with_sources_of_funding = inner_section.find('div', class_="tbody")
            if table_with_sources_of_funding:
              rows = table_with_sources_of_funding.find_all('div', class_="tr")
              for row in rows:
                td = row.find_all('div', class_="td")
                amount_raised = td[0].get_text()
                funding_type = td[1].get_text()
                funding_round_closing = td[2].get_text()
                investors_ = td[3].find_all('span', class_="MuiChip-label MuiChip-labelSmall css-tavflp")
                list_of_investors = []
                if len(investors_) > 1:
                  for investor in investors_:
                    list_of_investors.append(investor.get_text())
                elif len(investors_) == 1:
                  investors_ = td[3].get_text()
                  list_of_investors.append(investors_)
                else:
                  list_of_investors.append('N/A')
                
                source_object = {
                  'Amount Raised' : amount_raised,
                  'Funding Type' : funding_type,
                  'Funding Round Close' : funding_round_closing,
                  'Investors' : list_of_investors
                }
                
                sources.append(source_object)
        
        investments2 = 'N/A'
        investment_rounds = 'N/A'
        total_amount_of_profiles = 'N/A'
        investment_section = soup.find('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 e15qxe2m0 css-1o2y007")
        if investment_section:
          sub_section2 = investment_section.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-8 css-1l5mznc")
          if sub_section2:
            sub_section3 = sub_section2.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-item MuiGrid-spacing-xs-3 css-1ofn76x")
            if sub_section3:
              items_list_in_the_first_container1 = sub_section3.find_all('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 css-1s50f5r")
              if items_list_in_the_first_container1:
                #1 - Total amount raised
                if len(items_list_in_the_first_container1) > 1:
                  #I want to take the fist item in the list
                  item = items_list_in_the_first_container1[0].find('div', class_="MuiPaper-root MuiPaper-outlined MuiPaper-rounded index-paperBox css-f7fxqs")
                  if item:
                    item = item.find('div', class_="MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom index-count css-1axqeeq")
                    investment_rounds = item.get_text()
                if len(items_list_in_the_first_container1) >= 2:
                  #I want to take the fist item in the list
                  item = items_list_in_the_first_container1[1].find('div', class_="MuiPaper-root MuiPaper-outlined MuiPaper-rounded index-paperBox css-f7fxqs")
                  if item:
                    item = item.find('div', class_="MuiTypography-root MuiTypography-h6 MuiTypography-gutterBottom index-count css-1axqeeq")
                    total_amount_of_profiles = item.get_text()
        else:
          investment_rounds = 'N/A'
          total_amount_of_profiles = 'N/A'
        
        investment_sources = []
        investment_object = {}
        second_sub_section_of_funding = soup.find('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 e15qxe2m0 css-1o2y007")
        if second_sub_section_of_funding:
          container_with_table = second_sub_section_of_funding.find('div', class_="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-8 css-1l5mznc")
          if container_with_table:
            container_with_table = container_with_table.find('div', class_="MuiGrid-root MuiGrid-item MuiGrid-grid-xs-12 css-15j76c0")
            if container_with_table:
              container_with_table = container_with_table.find('div', class_="css-1hqnz7 e1xvby5o1")
              if container_with_table:
                table = container_with_table.find('div', class_="table")
                if table :
                  table_with_sources_of_investments = table.find('div', class_="tbody")
                  if table_with_sources_of_investments:
                    rows = table_with_sources_of_investments.find_all('div', class_="tr pointer")
                    for row in rows:
                      td = row.find_all('div', class_="td")
                      name = td[1].get_text() #1 --- Name

                      industries = td[2].find_all('span', class_="MuiChip-label MuiChip-labelSmall css-tavflp")
                      list_of_industries = [] #2 --- Industries
                      if len(industries) > 1:
                        for industry in industries:
                          list_of_industries.append(industry.get_text())
                      elif len(industries) == 1:
                        industry = td[2].get_text()
                        list_of_industries.append(industry)
                      else:
                        list_of_industries.append('N/A')
                      investment_use_cases = td[3].find_all("span", class_="MuiChip-label MuiChip-labelSmall css-tavflp")

                      list_of_investment_use_cases = [] #3 --- Investment use cases
                      if len(investment_use_cases) > 1:
                        for the_use_case in investment_use_cases:
                          list_of_investment_use_cases.append(the_use_case.get_text())
                      elif len(investment_use_cases) == 1:
                        the_use_case = td[3].get_text()
                        list_of_investment_use_cases.append(the_use_case)
                      else:
                        list_of_investment_use_cases.append('N/A')
                      
                      total_raised = td[4].get_text() #4 --- Total Raised

                      last_funding_round_date = td[5].get_text() #5 --- Last funding round data
                      
                      investment_object = {
                        'Investment Name' : name,
                        'Investment Industries' : list_of_industries,
                        'Investment Use Cases' : list_of_investment_use_cases,
                        'Total Raised' : total_raised,
                        'Last Funding Round Date' : last_funding_round_date
                      }
                      investment_sources.append(investment_object)


        funding_section_writer.writerow([profile_link, company_name, total_amount_raised, rounds,
              total_amount_of_investors, sources, investment_rounds, total_amount_of_profiles, investment_object]) 
                  

           
      partners_section_writer.writerow([profile_link, company_name])
      products_section_writer.writerow([profile_link, company_name])
      news_section_writer.writerow([profile_link, company_name])
      team_section_writer.writerow([profile_link, company_name, team_members])
      # if token_info != 'N/A' :
      #   tokens_section_writer.writerow([profile_link, company_name, token_names[0],token_info[1], token_info[2], token_info[3], token_info[4], token_info[5], token_info[6], token_info[7]]) 
      # else:
      #   tokens_section_writer.writerow([profile_link, company_name, 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A'])

      if len(token_info) >= 8:
        tokens_section_writer.writerow([profile_link, company_name, token_names[0], token_info[1], token_info[2], token_info[3], token_info[4], token_info[5], token_info[6], token_info[7]])
      else:
        tokens_section_writer.writerow([profile_link, company_name] + [token_info[i] if i < len(token_info) else 'N/A' for i in range(8)])
      


      time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 309
#     307 # Run the event loop in the notebook
#     308 loop = asyncio.get_event_loop()
# --> 309 profile_bio = loop.run_until_complete(get_profile_bio())
#     312 about_section_writer.writerow([profile_link, company_name,profile_bio,
#     313                    image_url, company_caption,
#     314                    company_description, based_in, website_url,
#    (...)
#     317                    total_amount_raised,team_size,number_of_clients,year_of_establishment,
#     318                    profile_type,status, key_objective, slogan_motto, use_cases, parent_organization,sub_organization, registered_entity_name ])
#     320 # Beginning scrap of the team section
#     321 # 25 - Team members section
#     322 #So in this section will come back later and scrap the responsibility which have a show more button
#
# File ~\AppData\Roaming\Python\Python310\site-packages\nest_asyncio.py:99, in _patch_loop.<locals>.run_until_complete(self, future)
#      96 if not f.done():
#      97     raise RuntimeError(
#      98         'Event loop stopped before Future completed.')
# ---> 99 return f.result()
#
# File c:\Users\Tino\AppData\Local\Programs\Python\Python310\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File c:\Users\Tino\AppData\Local\Programs\Python\Python310\lib\asyncio\tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[18], line 298, in get_profile_bio()
#     294     # await page.waitForSelector('.MuiGrid-root.MuiGrid-item.MuiGrid-grid-xs-12.MuiGrid-grid-sm-6.MuiGrid-grid-md-8.css-1yz5cc4', {'timeout': 10000})
#     296     extracted_text = await page.evaluate('document.querySelector(".MuiGrid-root.MuiGrid-item.MuiGrid-grid-xs-12.MuiGrid-grid-sm-6.MuiGrid-grid-md-8.css-1yz5cc4").textContent')
# --> 298     await browser.close()
#     299     return extracted_text
#     300 except TimeoutError:
#
# File c:\Users\Tino\AppData\Local\Programs\Python\Python310\lib\site-packages\pyppeteer\browser.py:262, in Browser.close(self)
#     260 async def close(self) -> None:
#     261     """Close connections and terminate browser process."""
# --> 262     await self._closeCallback()
#
# File c:\Users\Tino\AppData\Local\Programs\Python\Python310\lib\site-packages\pyppeteer\launcher.py:219, in Launcher.killChrome(self)
#     216 if self.temporaryUserDataDir and os.path.exists(self.temporaryUserDataDir):  # noqa: E501
#     217     # Force kill chrome only when using temporary userDataDir
#     218     self.waitForChromeToClose()
# --> 219     self._cleanup_tmp_user_data_dir()
#
# File c:\Users\Tino\AppData\Local\Programs\Python\Python310\lib\site-packages\pyppeteer\launcher.py:134, in Launcher._cleanup_tmp_user_data_dir(self)
#     132         break
#     133 else:
# --> 134     raise IOError('Unable to remove Temporary User Data')
#
# OSError: Unable to remove Temporary User Data

# %%
pip install nbconvert
# Out:
# Collecting nbconvert
#   Obtaining dependency information for nbconvert from https://files.pythonhosted.org/packages/a4/a6/072b6fd04616f1409f37ef5967ea5bbbeea1447d4494c2d98658a95fc985/nbconvert-7.8.0-py3-none-any.whl.metadata
#   Downloading nbconvert-7.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\tino\appdata\local\programs\python\python310\lib\site-packages (from nbconvert) (4.12.2)
# Collecting bleach!=5.0.0 (from nbconvert)
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ---------------------------------------- 0.0/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.5 kB ? eta -:--:--
#      ---- --------------------------------- 20.5/162.5 kB 32.7 kB/s eta 0:00:05
#      ------------- ----------------------- 61.4/162.5 kB 156.1 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.5 kB 156.1 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.5 kB 156.1 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.5 kB 156.1 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.5 kB 156.1 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.5 kB 156.1 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/162.5 kB 117.7 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/162.5 kB 124.9 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/162.5 kB 152.4 kB/s eta 0:00:01
#      --------------------------- -------- 122.9/162.5 kB 160.2 kB/s eta 0:00:01
#      ------------------------------- ---- 143.4/162.5 kB 177.5 kB/s eta 0:00:01
#      ---------------------------------- - 153.6/162.5 kB 183.6 kB/s eta 0:00:01
#      ---------------------------------- - 153.6/162.5 kB 183.6 kB/s eta 0:00:01
#      ---------------------------------- - 153.6/162.5 kB 183.6 kB/s eta 0:00:01
#      ------------------------------------ 162.5/162.5 kB 168.0 kB/s eta 0:00:00
# Collecting defusedxml (from nbconvert)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jinja2>=3.0 (from nbconvert)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ---------------------------------------- 0.0/133.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/133.1 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/133.1 kB 640.0 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/133.1 kB 388.9 kB/s eta 0:00:01
#      ----------------- ------------------- 61.4/133.1 kB 109.2 kB/s eta 0:00:01
#      ---------------------- -------------- 81.9/133.1 kB 147.8 kB/s eta 0:00:01
#      ------------------------- ----------- 92.2/133.1 kB 149.8 kB/s eta 0:00:01
#      --------------------------------- -- 122.9/133.1 kB 200.1 kB/s eta 0:00:01
#      --------------------------------- -- 122.9/133.1 kB 200.1 kB/s eta 0:00:01
#      ------------------------------------ 133.1/133.1 kB 187.0 kB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\tino\appdata\roaming\python\python310\site-packages (from nbconvert) (5.3.1)
# Collecting jupyterlab-pygments (from nbconvert)
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting markupsafe>=2.0 (from nbconvert)
#   Obtaining dependency information for markupsafe>=2.0 from https://files.pythonhosted.org/packages/84/a8/c4aebb8a14a1d39d5135eb8233a0b95831cdc42c4088358449c3ed657044/MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl.metadata
#   Downloading MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert)
#   Obtaining dependency information for mistune<4,>=2.0.3 from https://files.pythonhosted.org/packages/cc/c0/ac9587149e37cde62ae338e9db8241ae2fdc79a84bde8c8ba7caea2c22d8/mistune-3.0.1-py3-none-any.whl.metadata
#   Downloading mistune-3.0.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert)
#   Obtaining dependency information for nbclient>=0.5.0 from https://files.pythonhosted.org/packages/ac/5a/d670ca51e6c3d98574b9647599821590efcd811d71f58e9c89fc59a17685/nbclient-0.8.0-py3-none-any.whl.metadata
#   Downloading nbclient-0.8.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert)
#   Obtaining dependency information for nbformat>=5.7 from https://files.pythonhosted.org/packages/f4/e7/ef30a90b70eba39e675689b9eaaa92530a71d7435ab8f9cae520814e0caf/nbformat-5.9.2-py3-none-any.whl.metadata
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: packaging in c:\users\tino\appdata\roaming\python\python310\site-packages (from nbconvert) (23.1)
# Collecting pandocfilters>=1.4.1 (from nbconvert)
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\tino\appdata\roaming\python\python310\site-packages (from nbconvert) (2.16.1)
# Collecting tinycss2 (from nbconvert)
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: traitlets>=5.1 in c:\users\tino\appdata\roaming\python\python310\site-packages (from nbconvert) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\tino\appdata\roaming\python\python310\site-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tino\appdata\roaming\python\python310\site-packages (from jupyter-core>=4.7->nbconvert) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\tino\appdata\roaming\python\python310\site-packages (from jupyter-core>=4.7->nbconvert) (306)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\tino\appdata\roaming\python\python310\site-packages (from nbclient>=0.5.0->nbconvert) (8.3.0)
# Collecting fastjsonschema (from nbformat>=5.7->nbconvert)
#   Obtaining dependency information for fastjsonschema from https://files.pythonhosted.org/packages/9d/93/a3ca3cdeb84065d7d8f8df4cb09ab44405f109183c1d2b915ec17574e6b1/fastjsonschema-2.18.0-py3-none-any.whl.metadata
#   Downloading fastjsonschema-2.18.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting jsonschema>=2.6 (from nbformat>=5.7->nbconvert)
#   Obtaining dependency information for jsonschema>=2.6 from https://files.pythonhosted.org/packages/2b/ff/af59fd34bc4d7ac3e6e0cd1f3c10317d329b6c1aee179e8b24ad9a79fbac/jsonschema-4.19.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.19.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tino\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert) (2.4.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tino\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (23.1.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat>=5.7->nbconvert)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/1c/24/83349ac2189cc2435e84da3f69ba3c97314d3c0622628e55171c6798ed80/jsonschema_specifications-2023.7.1-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2023.7.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat>=5.7->nbconvert)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/be/8e/56d6f1e2d591f4d6cbcba446cac4a1b0dc4f584537e2071d9bcee8eeab6b/referencing-0.30.2-py3-none-any.whl.metadata
#   Downloading referencing-0.30.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat>=5.7->nbconvert)
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/6e/3a/e68cdb093488e2d1940b5eefb5fe21e3751c920f13e6d76c231be4fc82a1/rpds_py-0.10.0-cp310-none-win_amd64.whl.metadata
#   Downloading rpds_py-0.10.0-cp310-none-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tino\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\tino\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (25.1.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\tino\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.3.3)
# Downloading nbconvert-7.8.0-py3-none-any.whl (254 kB)
#    ---------------------------------------- 0.0/254.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/254.9 kB 1.3 MB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/254.9 kB 656.4 kB/s eta 0:00:01
#    -------------- ------------------------ 92.2/254.9 kB 163.8 kB/s eta 0:00:01
#    ---------------- --------------------- 112.6/254.9 kB 198.4 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/254.9 kB 318.9 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/254.9 kB 318.9 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/254.9 kB 318.9 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/254.9 kB 318.9 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/254.9 kB 318.9 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/254.9 kB 318.9 kB/s eta 0:00:01
#    --------------------------------- ---- 225.3/254.9 kB 264.8 kB/s eta 0:00:01
#    ------------------------------------ - 245.8/254.9 kB 284.4 kB/s eta 0:00:01
#    ------------------------------------ - 245.8/254.9 kB 284.4 kB/s eta 0:00:01
#    -------------------------------------- 254.9/254.9 kB 265.4 kB/s eta 0:00:00
# Downloading MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl (17 kB)
# Downloading mistune-3.0.1-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/48.0 kB ? eta -:--:--
#    ---------------------------------- ----- 41.0/48.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 41.0/48.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 48.0/48.0 kB 608.4 kB/s eta 0:00:00
# Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.1 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/73.1 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  71.7/73.1 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------  71.7/73.1 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 73.1/73.1 kB 576.9 kB/s eta 0:00:00
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/77.6 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/77.6 kB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 71.7/77.6 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 77.6/77.6 kB 724.2 kB/s eta 0:00:00
# Downloading jsonschema-4.19.0-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#    ---------------------------------------  81.9/83.4 kB 163.7 kB/s eta 0:00:01
#    ---------------------------------------  81.9/83.4 kB 163.7 kB/s eta 0:00:01
#    ---------------------------------------  81.9/83.4 kB 163.7 kB/s eta 0:00:01
#    ---------------------------------------- 83.4/83.4 kB 133.7 kB/s eta 0:00:00
# Downloading fastjsonschema-2.18.0-py3-none-any.whl (23 kB)
# Downloading jsonschema_specifications-2023.7.1-py3-none-any.whl (17 kB)
# Downloading referencing-0.30.2-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.10.0-cp310-none-win_amd64.whl (184 kB)
#    ---------------------------------------- 0.0/184.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/184.5 kB ? eta -:--:--
#    -------- ------------------------------ 41.0/184.5 kB 991.0 kB/s eta 0:00:01
#    -------- ------------------------------ 41.0/184.5 kB 991.0 kB/s eta 0:00:01
#    ------------ -------------------------- 61.4/184.5 kB 365.7 kB/s eta 0:00:01
#    --------------- ----------------------- 71.7/184.5 kB 393.8 kB/s eta 0:00:01
#    ----------------------- -------------- 112.6/184.5 kB 469.7 kB/s eta 0:00:01
#    ----------------------- -------------- 112.6/184.5 kB 469.7 kB/s eta 0:00:01
#    ------------------------- ------------ 122.9/184.5 kB 400.9 kB/s eta 0:00:01
#    ----------------------------- -------- 143.4/184.5 kB 448.2 kB/s eta 0:00:01
#    ----------------------------- -------- 143.4/184.5 kB 448.2 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ------------------------------- ------ 153.6/184.5 kB 367.6 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    ----------------------------------- -- 174.1/184.5 kB 214.2 kB/s eta 0:00:01
#    -------------------------------------  184.3/184.5 kB 166.3 kB/s eta 0:00:01
#    -------------------------------------- 184.5/184.5 kB 157.1 kB/s eta 0:00:00
# Installing collected packages: webencodings, fastjsonschema, tinycss2, rpds-py, pandocfilters, mistune, markupsafe, jupyterlab-pygments, defusedxml, bleach, referencing, jinja2, jsonschema-specifications, jsonschema, nbformat, nbclient, nbconvert
# Successfully installed bleach-6.0.0 defusedxml-0.7.1 fastjsonschema-2.18.0 jinja2-3.1.2 jsonschema-4.19.0 jsonschema-specifications-2023.7.1 jupyterlab-pygments-0.2.2 markupsafe-2.1.3 mistune-3.0.1 nbclient-0.8.0 nbconvert-7.8.0 nbformat-5.9.2 pandocfilters-1.5.0 referencing-0.30.2 rpds-py-0.10.0 tinycss2-1.2.1 webencodings-0.5.1
# Note: you may need to restart the kernel to use updated packages.
